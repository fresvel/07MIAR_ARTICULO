# %% [markdown]
# # Definición del Modelo

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv1D, BatchNormalization,
                                     MaxPooling1D, Flatten, Dense, Dropout, Activation)
from tensorflow.keras import backend as K
np.random.seed(42); tf.random.set_seed(42)

def build_1dcnn_16k(input_length=16000, num_classes=10, return_logits=True):
    inp = Input(shape=(input_length, 1), name="input_wave")
    
    # Conv1
    x = Conv1D(filters=16, kernel_size=64, strides=2, padding='valid', name='conv1')(inp)
    x = Activation('relu', name='relu1')(x)
    x = BatchNormalization(name='bn1')(x)
    x = MaxPooling1D(pool_size=8, strides=8, name='pool1')(x)
    
    # Conv2
    x = Conv1D(filters=32, kernel_size=32, strides=2, padding='valid', name='conv2')(x)
    x = Activation('relu', name='relu2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = MaxPooling1D(pool_size=8, strides=8, name='pool2')(x)
    
    # Conv3
    x = Conv1D(filters=64, kernel_size=16, strides=2, padding='valid', name='conv3')(x)
    x = Activation('relu', name='relu3')(x)
    x = BatchNormalization(name='bn3')(x)
    
    # Conv4
    x = Conv1D(filters=128, kernel_size=8, strides=2, padding='valid', name='conv4')(x)
    x = Activation('relu', name='relu4')(x)
    x = BatchNormalization(name='bn4')(x)
    
    # Dense
    x = Flatten(name='flatten')(x)
    x = Dense(128, name='fc1')(x)
    x = Activation('relu', name='relu_fc1')(x)
    x = Dropout(0.25, name='dropout1')(x)
    x = Dense(64, name='fc2')(x)
    x = Activation('relu', name='relu_fc2')(x)
    x = Dropout(0.25, name='dropout2')(x)
    
    logits = Dense(num_classes, name='logits')(x)          # <- pre-softmax
    probs  = Activation('softmax', name='softmax')(logits) # <- softmax
    
    model = Model(inputs=inp, outputs=probs, name='1D_CNN_16k')
    if return_logits:
        # modelo auxiliar que devuelve logits y probs
        model_logits = Model(inputs=inp, outputs=[logits, probs], name='1D_CNN_16k_with_logits')
        return model, model_logits
    return model

model, model_with_logits = build_1dcnn_16k()
# Out:
# 2025-10-29 17:32:44.226809: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-29 17:32:44.248320: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-29 17:32:45.059404: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
model.summary(line_length=110)
total_params = np.sum([K.count_params(w) for w in model.trainable_weights])
print("\nParámetros entrenables totales:", total_params)
# Out:
# Model: "1D_CNN_16k"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                                   ┃ Output Shape                        ┃             Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ input_wave (InputLayer)                        │ (None, 16000, 1)                    │                   0 │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ conv1 (Conv1D)                                 │ (None, 7969, 16)                    │               1,040 │
# ├────────────────────────────────────────────────┼─────────────────────────────────────┼─────────────────────┤
# │ relu1 (Activation)                             │ (None, 7969, 16)                    │                   0 │
# ...

# %% [markdown]
# # 3)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Crear una onda simulada de ejemplo: 1 segundo, 16 kHz
sample_rate = 16000
t = np.linspace(0, 1, sample_rate)
wave = 0.5 * np.sin(2 * np.pi * 440 * t)  # tono A4 (440 Hz)
wave = wave.reshape(1, sample_rate, 1)    # (batch_size, length, channels)

# 2. Mostrar forma
print("Forma del tensor de entrada:", wave.shape)

# 3. Visualizar una parte de la onda
plt.figure(figsize=(10, 3))
plt.plot(t[:800], wave[0, :800, 0])
plt.title("Ejemplo de entrada (onda seno 440 Hz, 1 s, 16 kHz)")
plt.xlabel("Tiempo (s)")
plt.ylabel("Amplitud")
plt.show()

# 4. Mostrar estadísticas básicas
print("Valor mínimo:", wave.min())
print("Valor máximo:", wave.max())
print("Media:", wave.mean())
print("Desviación estándar:", wave.std())
# Out:
# Forma del tensor de entrada: (1, 16000, 1)
# Valor mínimo: -0.49999999759012737
# Valor máximo: 0.49999999759012737
# Media: 5.051514762044462e-18
# Desviación estándar: 0.3535423418771788

# %%
import soundata

dataset = soundata.initialize('urbansound8k')
dataset.download()  # download the dataset
dataset.validate()  # validate that all the expected files are there

example_clip = dataset.choice_clip()  # choose a random example clip
print(example_clip)  # see the available data
# Out:
# INFO: Downloading ['all', 'index']. Index is being stored in /home/fresvel/.local/share/virtualenvs/Owner-87mVb6RR/lib/python3.12/site-packages/soundata/datasets/indexes, and the rest of files in /home/fresvel/sound_datasets/urbansound8k
# INFO: [all] downloading UrbanSound8K.tar.gz
# 5.61GB [1:56:19, 863kB/s]
# /home/fresvel/.local/share/virtualenvs/Owner-87mVb6RR/lib/python3.12/site-packages/soundata/download_utils.py:399: RuntimeWarning: The default behavior of tarfile extraction has been changed to disallow common exploits (including CVE-2007-4559). By default, absolute/parent paths are disallowed and some mode bits are cleared. See https://access.redhat.com/articles/7004769 for more details.
#   tfile.extractall(os.path.dirname(tar_path))
# INFO: [index] downloading urbansound8k_index_1.0.json
# 1.15MB [00:02, 494kB/s]
# ...
# 100%|██████████████████████████████████████████████████████████| 8732/8732 [00:20<00:00, 419.26it/s]
# ...

# %%
print(dataset.data_home)
# Out:
# /home/fresvel/sound_datasets/urbansound8k

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

# Ruta de ejemplo (ajusta a tu archivo real)
audio_path = "/home/fresvel/sound_datasets/urbansound8k/audio/fold1/101415-3-0-2.wav"

# 1. Cargar y convertir a mono a 16 kHz
wave, sr = librosa.load(audio_path, sr=16000, mono=True)
print(f"Frecuencia de muestreo: {sr} Hz, longitud: {len(wave)} muestras")

# 2. Normalizar a [-0.5, 0.5]
wave = wave / np.max(np.abs(wave)) * 0.5

# 3. Ajustar longitud (padding o recorte a 16,000)
if len(wave) < 16000:
    pad = 16000 - len(wave)
    wave = np.pad(wave, (0, pad))
else:
    wave = wave[:16000]

# 4. Dar forma para el modelo (batch, length, channels)
wave_input = wave.reshape(1, 16000, 1)

# Mostrar forma
print("Forma final:", wave_input.shape)

# Graficar la forma de onda
plt.figure(figsize=(10, 3))
plt.plot(np.linspace(0, 1, 16000), wave)
plt.title("Ejemplo de audio preprocesado (UrbanSound8k)")
plt.xlabel("Tiempo (s)")
plt.ylabel("Amplitud normalizada")
plt.show()

# Mostrar estadísticas
print("Valor mínimo:", wave.min())
print("Valor máximo:", wave.max())
print("Media:", wave.mean())
print("Desviación estándar:", wave.std())
# Out:
# Frecuencia de muestreo: 16000 Hz, longitud: 64000 muestras
# Forma final: (1, 16000, 1)
# Valor mínimo: -0.271793
# Valor máximo: 0.38556096
# Media: -1.0707752e-05
# Desviación estándar: 0.031052876

# %%
import numpy as np
import librosa

def preprocess_clip(clip, frame_size=16000, hop_size=8000):
    y, _ = librosa.load(clip.audio_path, sr=16000, mono=True)
    y = y / np.max(np.abs(y)) * 0.5
    frames = []
    for start in range(0, len(y) - frame_size + 1, hop_size):
        frame = y[start:start + frame_size]
        frames.append(frame.reshape(frame_size, 1))
    label = clip.tags.labels[0]
    return np.array(frames), label

# %%
from tqdm.notebook import tqdm


X, y = [], []

i=0

for clip_id in tqdm(dataset.clip_ids, desc="Procesando clips"):
    
    clip = dataset.clip(clip_id)
    frames, label = preprocess_clip(clip)
    X.extend(frames)
    y.extend([label] * len(frames))


X = np.array(X)
y = np.array(y)
print(X.shape, y.shape)
# Out:
# Procesando clips:   0%|          | 0/8732 [00:00<?, ?it/s]
# (53744, 16000, 1) (53744,)

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

le = LabelEncoder()
y_enc = to_categorical(le.fit_transform(y))

X_train, X_val, y_train, y_val = train_test_split(X, y_enc, test_size=0.1, random_state=42, stratify=y_enc)

# %%
model.compile(optimizer='Adadelta', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=100,
    validation_data=(X_val, y_val),
    callbacks=[],
    verbose=1
)
# Out:
# Epoch 1/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 80s 159ms/step - accuracy: 0.1046 - loss: 3.0408 - val_accuracy: 0.1295 - val_loss: 2.5285
# Epoch 2/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 79s 163ms/step - accuracy: 0.1262 - loss: 2.8823 - val_accuracy: 0.1635 - val_loss: 2.5009
# Epoch 3/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 81s 168ms/step - accuracy: 0.1427 - loss: 2.7600 - val_accuracy: 0.1885 - val_loss: 2.3985
# Epoch 4/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 84s 174ms/step - accuracy: 0.1588 - loss: 2.6532 - val_accuracy: 0.2180 - val_loss: 2.3138
# Epoch 5/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 85s 176ms/step - accuracy: 0.1770 - loss: 2.5586 - val_accuracy: 0.2435 - val_loss: 2.2411
# Epoch 6/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 86s 178ms/step - accuracy: 0.1935 - loss: 2.4879 - val_accuracy: 0.2592 - val_loss: 2.1799
# Epoch 7/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 87s 181ms/step - accuracy: 0.2054 - loss: 2.4214 - val_accuracy: 0.2763 - val_loss: 2.1279
# Epoch 8/50
# ...

# %%
# Guardar después de 50 epochs
model.save("articulo.keras")

# %%
# Cargar y continuar
from tensorflow.keras.models import load_model
model = load_model("articulo.keras")

# Continuar otros 50 epochs
history2 = model.fit(X_train, y_train, epochs=50, batch_size=100, validation_data=(X_val, y_val))
#summary(line_length=110)
# Out:
# /home/fresvel/.local/share/virtualenvs/Owner-87mVb6RR/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 24 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Epoch 1/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 82s 166ms/step - accuracy: 0.5709 - loss: 1.3100 - val_accuracy: 0.6214 - val_loss: 1.1845
# Epoch 2/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 82s 168ms/step - accuracy: 0.7022 - loss: 0.9320 - val_accuracy: 0.6657 - val_loss: 1.0412
# Epoch 3/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 86s 177ms/step - accuracy: 0.7507 - loss: 0.7783 - val_accuracy: 0.6242 - val_loss: 1.2785
# Epoch 4/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 86s 178ms/step - accuracy: 0.7776 - loss: 0.6826 - val_accuracy: 0.7652 - val_loss: 0.7108
# Epoch 5/50
# 484/484 ━━━━━━━━━━━━━━━━━━━━ 90s 185ms/step - accuracy: 0.7993 - loss: 0.6149 - val_accuracy: 0.7777 - val_loss: 0.6724
# ...

# %%
model.save("articulof2.keras")

# %%
# ============================================================
# 1. Librerías
# ============================================================
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv1D, BatchNormalization,
                                     MaxPooling1D, Flatten, Dense, Dropout, Activation)
from tensorflow.keras.utils import to_categorical, Sequence
from tensorflow.keras.optimizers import Adadelta
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
import librosa, gc, soundata

# ============================================================
# 2. Dataset UrbanSound8k
# ============================================================
#dataset = soundata.initialize('urbansound8k')
#dataset.download()
#dataset.validate()

# ============================================================
# 3. Arquitectura del modelo — 1D CNN (Abdoli et al., 2019)
# ============================================================
def build_1dcnn_16k(input_length=16000, num_classes=10):
    inp = Input(shape=(input_length, 1), name="input_wave")

    # Conv 1
    x = Conv1D(16, 64, strides=2, padding='valid', name='conv1')(inp)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(pool_size=8, strides=8, name='pool1')(x)

    # Conv 2
    x = Conv1D(32, 32, strides=2, padding='valid', name='conv2')(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(pool_size=8, strides=8, name='pool2')(x)

    # Conv 3
    x = Conv1D(64, 16, strides=2, padding='valid', name='conv3')(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)

    # Conv 4
    x = Conv1D(128, 8, strides=2, padding='valid', name='conv4')(x)
    x = Activation('relu')(x)
    x = BatchNormalization()(x)

    # Fully connected layers
    x = Flatten()(x)
    x = Dense(128, activation='relu', name='fc1')(x)
    x = Dropout(0.25)(x)
    x = Dense(64, activation='relu', name='fc2')(x)
    x = Dropout(0.25)(x)

    out = Dense(num_classes, activation='softmax', name='softmax')(x)
    return Model(inputs=inp, outputs=out, name="1D_CNN_16k")

# ============================================================
# 4. Generador de frames con 50 % de solapamiento
# ============================================================
class UrbanSoundGenerator(Sequence):
    def __init__(self, clip_ids, dataset, label_encoder,
                 batch_size=100, frame_size=16000, hop_size=8000, shuffle=True):
        self.clip_ids = clip_ids
        self.dataset = dataset
        self.le = label_encoder
        self.batch_size = batch_size
        self.frame_size = frame_size
        self.hop_size = hop_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.clip_ids) / self.batch_size))

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.clip_ids)

    def __getitem__(self, idx):
        batch_clips = self.clip_ids[idx*self.batch_size:(idx+1)*self.batch_size]
        X_batch, y_batch = [], []
        for clip_id in batch_clips:
            clip = self.dataset.clip(clip_id)
            y, _ = librosa.load(clip.audio_path, sr=16000, mono=True)
            y = y / (np.max(np.abs(y)) + 1e-9) * 0.5
            for start in range(0, len(y) - self.frame_size + 1, self.hop_size):
                frame = y[start:start + self.frame_size]
                X_batch.append(frame.reshape(self.frame_size, 1))
                y_batch.append(self.le.transform([clip.tags.labels[0]])[0])
        X_batch = np.array(X_batch, dtype=np.float32)
        y_batch = to_categorical(y_batch, num_classes=10)
        return X_batch, y_batch

# ============================================================
# 5. Configuración de folds estratificados (10-fold CV)
# ============================================================
labels = [dataset.clip(cid).tags.labels[0] for cid in dataset.clip_ids]
le = LabelEncoder().fit(labels)
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
fold_accuracies = []

# ============================================================
# 6. Entrenamiento fiel al paper
# ============================================================
for fold, (train_idx, val_idx) in enumerate(kf.split(dataset.clip_ids, le.transform(labels))):
    print(f"\n===== Fold {fold+1}/10 =====")
    train_ids = [dataset.clip_ids[i] for i in train_idx]
    val_ids   = [dataset.clip_ids[i] for i in val_idx]

    train_gen = UrbanSoundGenerator(train_ids, dataset, le, batch_size=100)
    val_gen   = UrbanSoundGenerator(val_ids, dataset, le, batch_size=100, shuffle=False)

    model = build_1dcnn_16k()
    opt = Adadelta(learning_rate=1.0)          # ⚠️ Igual que en el paper
    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(train_gen, validation_data=val_gen,
                        epochs=100, verbose=1)  # ⚠️ 100 épocas

    scores = model.evaluate(val_gen, verbose=0)
    fold_accuracies.append(scores[1])
    print(f"Fold {fold+1} Accuracy: {scores[1]*100:.2f}%")

    del model, train_gen, val_gen
    gc.collect()

print(f"\n=== Mean Accuracy: {np.mean(fold_accuracies)*100:.2f}% ± {np.std(fold_accuracies)*100:.2f}% ===")
